# %%
# Dependencies
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract JSON into DataFrames

# %%
# base url
base_url = "https://data.cdc.gov/api/views/r8kw-7aab/rows.json"

# run a request using our params dictionary
response = requests.get(base_url)

# %%
# convert response to json
cdc_data = response.json()

# Print the json (pretty printed)
print(json.dumps(cdc_data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         [
#             "row-v8c6-4u8p~xnb3",
#             "00000000-0000-0000-2684-A445700CEB78",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-01T00:00:00",
#             "2020-02-01T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "0",
#             "57581",
#             "0.97",
#             "3711",
#             "0",
#             "475",
#             "4186",
#             null
#         ],
#         [
#             "row-ubnx_reve_ashn",
#             "00000000-0000-0000-E579-8E4D0ABB6F6F",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-08T00:00:00",
#             "2020-02-08T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "1",
#             "58243",
#             "0.98",
#             "3714",
#             "0",
#             "507",
#             "4222",
#             null
#         ],
#         [
#             "row-yw6e.4q2v~3wa3",
#             "00000000-0000-0000-A79D-BD82753D8CF5",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-15T00:00:00",
#             "2020-02-15T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "0",
#             "57579",
#             "0.98",
#             "3746",
#             "0",
#             "540",
#             "4286",
#             null
#         ],
#         [
#             "row-grdh-fka4~bagy",
#             "00000000-0000-0000-A7CB-5C3B6EE873A3",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-22T00:00:00",
#             "2020-02-22T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "2",
#             "57634",
#             "0.99",
#             "3610",
#             "0",
#             "552",
#             "4164",
#             null
#         ],
#         [
#             "row-3cvv~h57e_puqy",
#             "00000000-0000-0000-A656-AB526AD8E66F",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-29T00:00:00",
#             "2020-02-29T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "6",
#             "57952",
#             "1.01",
#             "3727",
#             "4",
#             "630",
#             "4359",
#             null
#         ],
#         [
#             "row-r8qd-4kcu.4wp4",
#             "00000000-0000-0000-E8F4-8C4FC97F74D4",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-07T00:00:00",
#             "2020-03-07T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "32",
#             "57710",
#             "1",
#             "3816",
#             "16",
#             "609",
#             "4440",
#             null
#         ],
#         [
#             "row-zxbp_gig8_c8wn",
#             "00000000-0000-0000-7105-55367E2BB0A3",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-14T00:00:00",
#             "2020-03-14T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "51",
#             "56405",
#             "0.99",
#             "3816",
#             "26",
#             "600",
#             "4440",
#             null
#         ],
#         [
#             "row-p6wm.eb8w.pkt8",
#             "00000000-0000-0000-F944-306D81D73DE7",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "530",
#             "56777",
#             "1",
#             "4347",
#             "241",
#             "528",
#             "5158",
#             null
#         ],
#         [
#             "row-t3cb~jnm6-scyg",
#             "00000000-0000-0000-385D-062DB4946E60",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-28T00:00:00",
#             "2020-03-28T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "2951",
#             "60346",
#             "1.08",
#             "5899",
#             "1338",
#             "429",
#             "7892",
#             null
#         ],
#         [
#             "row-pcvm_iuib_7tvk",
#             "00000000-0000-0000-35A4-4EDF3D61089A",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-04T00:00:00",
#             "2020-04-04T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             "9123",
#             "68322",
#             "1.22",
#             "9344",
#             "4386",
#             "450",
#             "14309",
#             null
#         ],
#         [
#             "row-q6xz-4ggk_haqi",
#             "00000000-0000-0000-F7E5-B5D43E24E05C",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-11T00:00:00",
#             "2020-04-11T00:00:00",
#             "By week",
#             "United States",
#             "Week-ending",
#             
00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "0",
#             "1059",
#             "0.98",
#             "59",
#             "0",
#             null,
#             "65",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-wnqw.avpi.xcth",
#             "00000000-0000-0000-CAC9-C0BE60159804",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             null,
#             "1034",
#             "1.01",
#             "72",
#             null,
#             null,
#             "79",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-tj72_i3uq~bmuc",
#             "00000000-0000-0000-A8A3-96C3EFEC52E1",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-28T00:00:00",
#             "2020-03-28T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "20",
#             "1030",
#             "1.01",
#             "68",
#             null,
#             null,
#             "89",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-gpif_jwbu-p4q9",
#             "00000000-0000-0000-223D-826D14DBFFF7",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-04T00:00:00",
#             "2020-04-04T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "49",
#             "1112",
#             "1.08",
#             "64",
#             "11",
#             null,
#             "104",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-44fj_59rd~rj3v",
#             "00000000-0000-0000-8608-537D0D46D1DF",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-11T00:00:00",
#             "2020-04-11T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "77",
#             "1080",
#             "1.05",
#             "82",
#             "25",
#             null,
#             "137",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-8cyw-s2gy.fucp",
#             "00000000-0000-0000-9FA8-9CA20E25964D",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-18T00:00:00",
#             "2020-04-18T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "81",
#             "1054",
#             "1.07",
#             "89",
#             "24",
#             "0",
#             "146",
#             null
#         ],
#         [
#             "row-pzj2.fswu-cqdt",
#             "00000000-0000-0000-26E2-E0B72E24B150",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-25T00:00:00",
#             "2020-04-25T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "61",
#             "984",
#             "0.98",
#             "67",
#             "16",
#             null,
#             "113",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-mgjb~ftgv-x829",
#             "00000000-0000-0000-E9E2-05A1438F6BFB",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-02T00:00:00",
#             "2020-05-02T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "50",
#             "923",
#             "0.93",
#             "67",
#             "13",
#             null,
#             "105",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-jykg.6uf9~d8qf",
#             "00000000-0000-0000-EBE0-D37ABB949B0E",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-09T00:00:00",
#             "2020-05-09T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "31",
#             "682",
#             "0.68",
#             "50",
#             null,
#             "0",
#             "72",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-ujaj-is9q_2mgs",
#             "00000000-0000-0000-57CF-744C1E3C159B",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-16T00:00:00",
#             "2020-05-16T00:00:00",
#             "By week",
#             "Alabama",
#             "Week-ending",
#             "11",
#             "282",
#             "0.28",
#             "11",
#             null,
#             null,
#             "19",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-k6gm~us29_neas",
#             "00000000-0000-0000-85D1-C7E13F64EC4E",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-01T00:00:00",
#             "2020-02-01T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "83",
#             "0.93",
#             "0",
#             "0",
#             null,
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-e3s9_r4vs.ngwk",
#             "00000000-0000-0000-7B7A-E073F908BC1D",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-08T00:00:00",
#             "2020-02-08T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "92",
#             "1.23",
#             null,
#             "0",
#             null,
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-3svs~8z69~m87c",
#             "00000000-0000-0000-FF1E-128167EB2375",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-15T00:00:00",
#             "2020-02-15T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "88",
#             "1.01",
#             "0",
#             "0",
#             "0",
#             "0",
#             null
#         ],
#         [
#             "row-tmr4-h4kp~f3j9",
#             "00000000-0000-0000-5CB9-08514B1B60EF",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-22T00:00:00",
#             "2020-02-22T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "83",
#             "1.02",
#             null,
#             "0",
#             null,
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-x6c6-9cbp~iq72",
#             "00000000-0000-0000-B2A6-2779AE024A29",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-29T00:00:00",
#             "2020-02-29T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "78",
#             "0.93",
#             null,
#             "0",
#             null,
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-siqu_fwi5-sq7c",
#             "00000000-0000-0000-994F-5EDC44FDFA81",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-07T00:00:00",
#             "2020-03-07T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "78",
#             "0.91",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-5459-rs4k-gsux",
#             "00000000-0000-0000-0B33-EBC73F814F78",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-14T00:00:00",
#             "2020-03-14T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "87",
#             "1.03",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-xz65_xgzu-ruas",
#             "00000000-0000-0000-D152-F67232B28B17",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "64",
#             "0.8",
#             null,
#             "0",
#             null,
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-xaws-854z_hzci",
#             "00000000-0000-0000-F252-57B2B39BACB6",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-28T00:00:00",
#             "2020-03-28T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             null,
#             "79",
#             "0.92",
#             null,
#             null,
#             null,
#             "10",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-hrp4_bawa.dazd",
#             "00000000-0000-0000-4508-426929D4B89F",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-04T00:00:00",
#             "2020-04-04T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             null,
#             "92",
#             "1.06",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-nbzs-7778~2rvq",
#             "00000000-0000-0000-6EA5-3C93230C297B",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-11T00:00:00",
#             "2020-04-11T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             null,
#             "76",
#             "0.88",
#             null,
#             null,
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-pp9i.v5s7.dsuj",
#             "00000000-0000-0000-A996-2FCE5B8C5ABA",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-18T00:00:00",
#             "2020-04-18T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             null,
#             "66",
#             "0.85",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-u5hk_77ee_mcbm",
#             "00000000-0000-0000-1A04-1A0CE36DF50B",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-25T00:00:00",
#             "2020-04-25T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "48",
#             "0.61",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-gx9q_furd_a689",
#             "00000000-0000-0000-9227-31E56C3E4F85",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-02T00:00:00",
#             "2020-05-02T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "56",
#             "0.63",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-nxnm-qz3c_mvx2",
#             "00000000-0000-0000-CD9B-E10CA4921E4E",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-09T00:00:00",
#             "2020-05-09T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             null,
#             "42",
#             "0.54",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-h5c7~qifr.zbr5",
#             "00000000-0000-0000-BA4D-6B7C296DF048",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-05-16T00:00:00",
#             "2020-05-16T00:00:00",
#             "By week",
#             "Alaska",
#             "Week-ending",
#             "0",
#             "13",
#             "0.17",
#             null,
#             "0",
#             "0",
#             null,
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-4ymb~6gv7.s63t",
#             "00000000-0000-0000-86AC-9070CD52360E",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-01T00:00:00",
#             "2020-02-01T00:00:00",
#             "By week",
#             "Arizona",
#             "Week-ending",
#             "0",
#             "1262",
#             "0.99",
#             "74",
#             "0",
#             "13",
#             "87",
#             null
#         ],
#         [
#             "row-qv9z~7a7b~tnhm",
#             "00000000-0000-0000-430A-2FB72CA49375",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-08T00:00:00",
#             "2020-02-08T00:00:00",
#             "By week",
#             "Arizona",
#             "Week-ending",
#             "0",
#             "1258",
#             "1.01",
#             "79",
#             "0",
#             "10",
#             "89",
#             null
#         ],
#         [
#             "row-9jff.appt_mriy",
#             "00000000-0000-0000-7C26-6C6EA4CC4E34",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-15T00:00:00",
#             "2020-02-15T00:00:00",
#             "By week",
#             "Arizona",
#             "Week-ending",
#             "0",
#             "1308",
#             "1.1",
#             "91",
#             "0",
#             "13",
#             "104",
#             null
#         ],
#         [
#             "row-6zd3-d3sx_ab7c",
#             "00000000-0000-0000-76EB-D52007B6EB38",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02

#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-ww3q.ku4f~hgfr",
#             "00000000-0000-0000-D114-82357D123769",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-01T00:00:00",
#             "2020-02-01T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "678",
#             "1.04",
#             "55",
#             "0",
#             null,
#             "63",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-929q~tmn2~uzya",
#             "00000000-0000-0000-72F5-811CF48AC595",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-08T00:00:00",
#             "2020-02-08T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "669",
#             "1.02",
#             "49",
#             "0",
#             null,
#             "58",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-zrit-8acd-r6mj",
#             "00000000-0000-0000-200A-9A7CAC383130",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-15T00:00:00",
#             "2020-02-15T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "686",
#             "1.02",
#             "38",
#             "0",
#             null,
#             "43",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-4b3s_ni9i-h9bf",
#             "00000000-0000-0000-B6C5-7FC4D0FBD69D",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-22T00:00:00",
#             "2020-02-22T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "691",
#             "1.01",
#             "49",
#             "0",
#             "12",
#             "61",
#             null
#         ],
#         [
#             "row-3yey~yjrr_8m5m",
#             "00000000-0000-0000-0F79-0CA19D939C81",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-02-29T00:00:00",
#             "2020-02-29T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "653",
#             "1.02",
#             "32",
#             "0",
#             null,
#             "39",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-eqb7~3k7x~sjuw",
#             "00000000-0000-0000-45F2-39152A3DC675",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-07T00:00:00",
#             "2020-03-07T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "693",
#             "1.05",
#             "42",
#             "0",
#             null,
#             "51",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-r3kg_a49v_fqys",
#             "00000000-0000-0000-C067-C19E8F211D41",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-14T00:00:00",
#             "2020-03-14T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "623",
#             "0.97",
#             "37",
#             "0",
#             null,
#             "41",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-5syd-vhf9~t7ij",
#             "00000000-0000-0000-147E-8DBF114FF88C",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "2020-03-21T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "0",
#             "631",
#             "1",
#             "53",
#             "0",
#             "11",
#             "64",
#             null
#         ],
#         [
#             "row-8dx4.hv5p-ikd2",
#             "00000000-0000-0000-020B-1B9B98D75988",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-03-28T00:00:00",
#             "2020-03-28T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             null,
#             "626",
#             "0.99",
#             "40",
#             "0",
#             null,
#             "49",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-zvu8_ursj-teav",
#             "00000000-0000-0000-3D66-5C9428F25899",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-04T00:00:00",
#             "2020-04-04T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             null,
#             "603",
#             "0.99",
#             "50",
#             null,
#             "0",
#             "57",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-8jxt_yn5u~5bp7",
#             "00000000-0000-0000-E019-56E8D38F9E8D",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-11T00:00:00",
#             "2020-04-11T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "12",
#             "623",
#             "0.98",
#             "56",
#             null,
#             null,
#             "65",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-e9ms.iczu-ffue",
#             "00000000-0000-0000-31C6-51F926D6DBC2",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-18T00:00:00",
#             "2020-04-18T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "10",
#             "623",
#             "1.06",
#             "49",
#             null,
#             "0",
#             "54",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-q2f2-hig2-ynv6",
#             "00000000-0000-0000-06AD-0A3ED090181A",
#             0,
#             1590071875,
#             null,
#             1590071875,
#             null,
#             "{ }",
#             "2020-05-21T00:00:00",
#             "2020-04-25T00:00:00",
#             "2020-04-25T00:00:00",
#             "By week",
#             "Arkansas",
#             "Week-ending",
#             "13",
#             "579",
#             "0.98",
#             "40",
#             null,
#             "0",
#             "50",
#             "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#         ],
#         [
#             "row-wetv.c28a~32zr",
# ...
#                             {
#                                 "count": "6",
#                                 "item": "26"
#                             },
#                             {
#                                 "count": "6",
#                                 "item": "19"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "15"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "21"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "31"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "41"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "25"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "81"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "22"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "29"
#                             },
#                             {
#                                 "count": "3",
#                                 "item": "84"
#                             },
#                             {
#                                 "count": "3",
#                                 "item": "72"
#                             },
#                             {
#                                 "count": "3",
#                                 "item": "45"
#                             }
#                         ]
#                     },
#                     "dataTypeName": "number",
#                     "description": "Deaths with Pneumonia and COVID-19 (ICD-10 codes J12.0-J18.9 and U07.1)",
#                     "fieldName": "pneumonia_and_covid_deaths",
#                     "format": {
#                         "align": "right"
#                     },
#                     "id": 469053035,
#                     "name": "Pneumonia and COVID-19 Deaths",
#                     "position": 11,
#                     "renderTypeName": "number",
#                     "tableColumnId": 100321417
#                 },
#                 {
#                     "cachedContents": {
#                         "cardinality": "58",
#                         "largest": "630",
#                         "non_null": "430",
#                         "null": "434",
#                         "smallest": "0",
#                         "top": [
#                             {
#                                 "count": "210",
#                                 "item": "0"
#                             },
#                             {
#                                 "count": "21",
#                                 "item": "10"
#                             },
#                             {
#                                 "count": "20",
#                                 "item": "13"
#                             },
#                             {
#                                 "count": "19",
#                                 "item": "14"
#                             },
#                             {
#                                 "count": "18",
#                                 "item": "11"
#                             },
#                             {
#                                 "count": "17",
#                                 "item": "16"
#                             },
#                             {
#                                 "count": "11",
#                                 "item": "12"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "17"
#                             },
#                             {
#                                 "count": "9",
#                                 "item": "15"
#                             },
#                             {
#                                 "count": "7",
#                                 "item": "21"
#                             },
#                             {
#                                 "count": "6",
#                                 "item": "19"
#                             },
#                             {
#                                 "count": "6",
#                                 "item": "23"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "30"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "26"
#                             },
#                             {
#                                 "count": "5",
#                                 "item": "18"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "24"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "22"
#                             },
#                             {
#                                 "count": "4",
#                                 "item": "20"
#                             },
#                             {
#                                 "count": "3",
#                                 "item": "27"
#                             },
#                             {
#                                 "count": "2",
#                                 "item": "28"
#                             }
#                         ]
#                     },
#                     "dataTypeName": "number",
#                     "description": "Influenza Deaths (ICD-10 codes J09-J11)",
#                     "fieldName": "influenza_deaths",
#                     "format": {
#                         "align": "right"
#                     },
#                     "id": 469053037,
#                     "name": "Influenza Deaths",
#                     "position": 12,
#                     "renderTypeName": "number",
#                     "tableColumnId": 100321416
#                 },
#                 {
#                     "cachedContents": {
#                         "cardinality": "309",
#                         "largest": "19492",
#                         "non_null": "798",
#                         "null": "66",
#                         "smallest": "0",
#                         "top": [
#                             {
#                                 "count": "18",
#                                 "item": "11"
#                             },
#                             {
#                                 "count": "14",
#                                 "item": "18"
#                             },
#                             {
#                                 "count": "14",
#                                 "item": "21"
#                             },
#                             {
#                                 "count": "11",
#                                 "item": "43"
#                             },
#                             {
#                                 "count": "11",
#                                 "item": "10"
#                             },
#                             {
#                                 "count": "11",
#                                 "item": "19"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "20"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "22"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "25"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "118"
#                             },
#                             {
#                                 "count": "10",
#                                 "item": "13"
#                             },
#                             {
#                                 "count": "9",
#                                 "item": "14"
#                             },
#                             {
#                                 "count": "8",
#                                 "item": "26"
#                             },
#                             {
#                                 "count": "8",
#                                 "item": "56"
#                             },
#                             {
#                                 "count": "8",
#                                 "item": "27"
#                             },
#                             {
#                                 "count": "8",
#                                 "item": "0"
#                             },
#                             {
#                                 "count": "8",
#                                 "item": "34"
#                             },
#                             {
#                                 "count": "7",
#                                 "item": "71"
#                             },
#                             {
#                                 "count": "7",
#                                 "item": "55"
#                             },
#                             {
#                                 "count": "7",
#                                 "item": "31"
#                             }
#                         ]
#                     },
#                     "dataTypeName": "number",
#                     "description": "Pneumonia, Influenza, or COVID-19 Deaths (ICD-10 codes J12.0-J18.9, J09-J11, U07.1)",
#                     "fieldName": "pneumonia_influenza_or_covid_19_deaths",
#                     "format": {
#                         "align": "right"
#                     },
#                     "id": 469053089,
#                     "name": "Pneumonia, Influenza, or COVID-19 Deaths",
#                     "position": 13,
#                     "renderTypeName": "number",
#                     "tableColumnId": 102254271
#                 },
#                 {
#                     "cachedContents": {
#                         "cardinality": "1",
#                         "largest": "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards.",
#                         "non_null": "597",
#                         "null": "267",
#                         "smallest": "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards.",
#                         "top": [
#                             {
#                                 "count": "597",
#                                 "item": "One or more data cells have counts between 1\u20139 and have been suppressed in accordance with NCHS confidentiality standards."
#                             }
#                         ]
#                     },
#                     "dataTypeName": "text",
#                     "description": "Suppressed counts (1-9)",
#                     "fieldName": "footnote",
#                     "format": {},
#                     "id": 469053040,
#                     "name": "Footnote",
#                     "position": 14,
#                     "renderTypeName": "text",
#                     "tableColumnId": 100321425
#                 }
#             ],
#             "createdAt": 1588346786,
#             "description": "Deaths involving coronavirus disease 2019 (COVID-19), pneumonia, and influenza reported to NCHS by week ending date and by state",
#             "displayType": "table",
#             "downloadCount": 9137,
#             "flags": [
#                 "default",
#                 "restorable",
#                 "restorePossibleForType"
#             ],
#             "grants": [
#                 {
#                     "flags": [
#                         "public"
#                     ],
#                     "inherited": false,
#                     "type": "viewer"
#                 }
#             ],
#             "hideFromCatalog": false,
#             "hideFromDataJson": false,
#             "id": "r8kw-7aab",
#             "license": {
#                 "name": "Public Domain U.S. Government",
#                 "termsLink": "https://www.usa.gov/government-works"
#             },
#             "licenseId": "USGOV_WORKS",
#             "metadata": {
#                 "availableDisplayTypes": [
#                     "table",
#                     "fatrow",
#                     "page"
#                 ],
#                 "custom_fields": {
#                     "Common Core": {
#                         "Bureau Code": "009:20",
#                         "Contact Email": "cdcinfo@cdc.gov",
#                         "Contact Name": "National Center for Health Statistics",
#                         "Footnotes": "Number of deaths reported in this table are the total number of deaths received and coded as of the date of analysis, and do not represent all deaths that occurred in that period. Data during this period are incomplete because of the lag in time between when the death occurred and when the death certificate is completed, submitted to NCHS and processed for reporting purposes. This delay can range from 1 week to 8 weeks or more.  Percent of expected deaths is the number of deaths for all causes for this week in 2020 compared to the average number across the same week in 2017\u20132019. Previous analyses of 2015\u20132016 provisional data completeness have found that completeness is lower in the first few weeks following the date of death (<25%), and then increases over time such that data are generally at least 75% complete within 8 weeks of when the death occurred.",
#                         "Geographic Coverage": "United States",
#                         "Program Code": "009:020"
#                     }
#                 }
#             },
#             "name": "Provisional COVID-19 Death Counts by Week Ending Date and State",
#             "newBackend": true,
#             "numberOfComments": 0,
#             "oid": 34197414,
#             "owner": {
#                 "displayName": "NCHS",
#                 "flags": [
#                     "acceptedEula"
#                 ],
#                 "id": "xfvr-ns68",
#                 "screenName": "NCHS",
#                 "type": "interactive",
#                 "userSegment": "site_member"
#             },
#             "provenance": "official",
#             "publicationAppendEnabled": false,
#             "publicationDate": 1589988338,
#             "publicationGroup": 17081396,
#             "publicationStage": "published",
#             "query": {},
#             "rights": [
#                 "read"
#             ],
#             "rowsUpdatedAt": 1590071875,
#             "rowsUpdatedBy": "x3ra-dgbv",
#             "tableAuthor": {
#                 "displayName": "NCHS",
#                 "flags": [
#                     "acceptedEula"
#                 ],
#                 "id": "xfvr-ns68",
#                 "screenName": "NCHS",
#                 "type": "interactive",
#                 "userSegment": "site_member"
#             },
#             "tableId": 17141764,
#             "tags": [
#                 "coronavirus",
#                 "week",
#                 "state",
#                 "united states",
#                 "nchs",
#                 "covid-19",
#                 "mortality",
#                 "death",
#                 "pneumonia",
#                 "influenza"
#             ],
#             "totalTimesRated": 0,
#             "viewCount": 111921,
#             "viewLastModified": 1590071874,
#             "viewType": "tabular"
#         }
#     }
# }

# %%
print(cdc_data["data"][0])
# Out:
# ['row-v8c6-4u8p~xnb3', '00000000-0000-0000-2684-A445700CEB78', 0, 1590071875, None, 1590071875, None, '{ }', '2020-05-21T00:00:00', '2020-02-01T00:00:00', '2020-02-01T00:00:00', 'By week', 'United States', 'Week-ending', '0', '57581', '0.97', '3711', '0', '475', '4186', None]

# %% [markdown]
# ### Transform CDC Data into DataFrame

# %%
# Creating an empty Dataframe with column names only
cdc_data_df = pd.DataFrame(columns=['state','start_week', 'COVID_deaths', 'pneumonia_deaths','pneumonia_and_COVID_deaths',
                                    'influenza_deaths', 'pneumonia_influenzaor_COVID_deaths', 'total_deaths'])

# %%
# use iterrows to iterate through pandas dataframe
index = 0
for row in cdc_data["data"]:
    row = row
    try:
        cdc_data_df.loc[index, 'start_week'] = row[9]
        cdc_data_df.loc[index, 'state'] = row[12]
        cdc_data_df.loc[index, 'COVID_deaths'] = row[14]
        cdc_data_df.loc[index, 'pneumonia_deaths'] = row[17]
        cdc_data_df.loc[index, 'pneumonia_and_COVID_deaths'] =row[18]
        cdc_data_df.loc[index, 'influenza_deaths'] = row[19]
        cdc_data_df.loc[index, 'pneumonia_influenzaor_COVID_deaths'] = row[20]
        cdc_data_df.loc[index, 'total_deaths'] = row[15]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    index = index +1

# %%
cdc_data_df['start_week'] = pd.to_datetime(cdc_data_df['start_week']).dt.strftime('%m/%d/%Y')

# %%
# Set index
#cdc_data_df.set_index("state", inplace=True)
cdc_data_df = cdc_data_df.fillna(0)
cdc_data_df
# Out:
#              state  start_week COVID_deaths pneumonia_deaths  \
# 0    United States  02/01/2020            0             3711
# 1    United States  02/08/2020            1             3714
# 2    United States  02/15/2020            0             3746
# 3    United States  02/22/2020            2             3610
# 4    United States  02/29/2020            6             3727
# ..             ...         ...          ...              ...
# 859    Puerto Rico  04/18/2020           18               56
# 860    Puerto Rico  04/25/2020           17               53
# 861    Puerto Rico  05/02/2020           13               30
# 862    Puerto Rico  05/09/2020            0               15
# 863    Puerto Rico  05/16/2020            0                0
#
#     pneumonia_and_COVID_deaths influenza_deaths  \
# 0                            0              475
# 1                            0              507
# 2                            0              540
# 3                            0              552
# 4                            4              630
# ..                         ...              ...
# 859                          0                0
# 860                          0                0
# 861                          0                0
# 862                          0                0
# 863                          0                0
#
#     pneumonia_influenzaor_COVID_deaths total_deaths
# 0                                 4186        57581
# 1                                 4222        58243
# 2                                 4286        57579
# 3                                 4164        57634
# 4                                 4359        57952
# ..                                 ...          ...
# 859                                 68          439
# 860                                 65          370
# 861                                 41          222
# 862                                 16           90
# 863                                  0           31
#
# [864 rows x 8 columns]

# %% [markdown]
# ### Cleaning the CDC Data to megre with John Hopkins Data

# %%
# deleting row 0 to 16 as they are for united states as a whole
cdc_data_df = cdc_data_df[16:]
cdc_data_df
# Out:
#            state  start_week COVID_deaths pneumonia_deaths  \
# 16       Alabama  02/01/2020            0               55
# 17       Alabama  02/08/2020            0               61
# 18       Alabama  02/15/2020            0               75
# 19       Alabama  02/22/2020            0               67
# 20       Alabama  02/29/2020            0               63
# ..           ...         ...          ...              ...
# 859  Puerto Rico  04/18/2020           18               56
# 860  Puerto Rico  04/25/2020           17               53
# 861  Puerto Rico  05/02/2020           13               30
# 862  Puerto Rico  05/09/2020            0               15
# 863  Puerto Rico  05/16/2020            0                0
#
#     pneumonia_and_COVID_deaths influenza_deaths  \
# 16                           0               14
# 17                           0               10
# 18                           0                0
# 19                           0                0
# 20                           0               14
# ..                         ...              ...
# 859                          0                0
# 860                          0                0
# 861                          0                0
# 862                          0                0
# 863                          0                0
#
#     pneumonia_influenzaor_COVID_deaths total_deaths
# 16                                  69         1019
# 17                                  71         1107
# 18                                  81         1079
# 19                                  71         1080
# 20                                  77         1143
# ..                                 ...          ...
# 859                                 68          439
# 860                                 65          370
# 861                                 41          222
# 862                                 16           90
# 863                                  0           31
#
# [848 rows x 8 columns]

# %%
cdc_data_df = cdc_data_df.astype({'COVID_deaths': 'int64'})
cdc_data_df = cdc_data_df.astype({'pneumonia_deaths':'int64'})
cdc_data_df = cdc_data_df.astype({'pneumonia_and_COVID_deaths': 'int64'})
cdc_data_df = cdc_data_df.astype({'influenza_deaths':'int64'})
cdc_data_df = cdc_data_df.astype({'pneumonia_influenzaor_COVID_deaths': 'int64'})
cdc_data_df = cdc_data_df.astype({'total_deaths':'int64'})

# %%
cdc_data_df.dtypes
# Out:
# state                                 object
# start_week                            object
# COVID_deaths                           int64
# pneumonia_deaths                       int64
# pneumonia_and_COVID_deaths             int64
# influenza_deaths                       int64
# pneumonia_influenzaor_COVID_deaths     int64
# total_deaths                           int64
# dtype: object

# %%
#selecting only data from 04/25/2020 to 05/20/2020
cdc_may_data = cdc_data_df.loc[cdc_data_df["start_week"] >= "04/25/2020"]
cdc_may_data
# Out:
#            state  start_week  COVID_deaths  pneumonia_deaths  \
# 28       Alabama  04/25/2020            61                67
# 29       Alabama  05/02/2020            50                67
# 30       Alabama  05/09/2020            31                50
# 31       Alabama  05/16/2020            11                11
# 44        Alaska  04/25/2020             0                 0
# ..           ...         ...           ...               ...
# 847      Wyoming  05/16/2020             0                 0
# 860  Puerto Rico  04/25/2020            17                53
# 861  Puerto Rico  05/02/2020            13                30
# 862  Puerto Rico  05/09/2020             0                15
# 863  Puerto Rico  05/16/2020             0                 0
#
#      pneumonia_and_COVID_deaths  influenza_deaths  \
# 28                           16                 0
# 29                           13                 0
# 30                            0                 0
# 31                            0                 0
# 44                            0                 0
# ..                          ...               ...
# 847                           0                 0
# 860                           0                 0
# 861                           0                 0
# 862                           0                 0
# 863                           0                 0
#
#      pneumonia_influenzaor_COVID_deaths  total_deaths
# 28                                  113           984
# 29                                  105           923
# 30                                   72           682
# 31                                   19           282
# 44                                    0            48
# ..                                  ...           ...
# 847                                   0            35
# 860                                  65           370
# 861                                  41           222
# 862                                  16            90
# 863                                   0            31
#
# [212 rows x 8 columns]

# %%
cdc_may_group_data = cdc_may_data.groupby(['state']).sum()
cdc_may_group_data
# Out:
#                       COVID_deaths  pneumonia_deaths  \
# state
# Alabama                        153               195
# Alaska                           0                 0
# Arizona                        258               334
# Arkansas                        26               106
# California                    1099              1615
# Colorado                       464               363
# Connecticut                     45                 0
# Delaware                       120                54
# District of Columbia           100               114
# Florida                        723              1134
# Georgia                        439               410
# Hawaii                           0                17
# Idaho                           12                28
# Louisiana                                            528          2348
# Maine                                                 89          1029
# Maryland                                            1280          4596
# Massachusetts                                       3428          7227
# Michigan                                            1564          6346
# Minnesota                                            618          3362
# Mississippi                                          326          2016
# Missouri                                             431          3648
# Montana                                               11           449
# Nebraska                                             106          1035
# Nevada                                               206          1570
# New Hampshire                                        170          1002
# New Jersey                                          3635          8427
# New Mexico                                           158          1011
# New York                                            3778         10167
# New York City                                       4939          8781
# North Carolina                                        40            40
# North Dakota                                          27           316
# Ohio                                                 630          5610
# Oklahoma                                             151          1339
# Oregon                                               112          1767
# Pennsylvania                                        2523         10383
# Puerto Rico                                          122           713
# Rhode Island                                         175           450
# South Carolina                                       348          3214
# South Dakota                                          36           410
# Tennessee                                            337          4398
# Texas                                               1060         11235
# Utah                                                  85          1394
# Vermont                                               17           382
# Virginia                                             766          4698
# Washington                                           278          3303
# West Virginia                                         42           309
# Wisconsin                                            311          3447
# Wyoming                                               11           241

# %%
# Save Data to csv
cdc_may_group_data.to_csv("cdc_may_group_data.csv")

# Visualize to confirm cdc data appears
cdc_may_group_data.head(20)
# Out:
#                       COVID_deaths  pneumonia_deaths  \
# state
# Alabama                        153               195
# Alaska                           0                 0
# Arizona                        258               334
# Arkansas                        26               106
# California                    1099              1615
# Colorado                       464               363
# Connecticut                     45                 0
# Delaware                       120                54
# District of Columbia           100               114
# Florida                        723              1134
# Georgia                        439               410
# Hawaii                           0                17
# Idaho                           12                28
# Illinois                      1646              1271
# Indiana                        547               476
# Iowa                           188               133
# Kansas                          55                97
# Kentucky                       103               192
# Louisiana                      440               306
# Maine                           18                49
#
#                       pneumonia_and_COVID_deaths  influenza_deaths  \
# state
# Alabama                                       29                 0
# Alaska                                         0                 0
# Arizona                                      114                 0
# Arkansas                                       0                 0
# California                                   615                 0
# Colorado                                     219                 0
# Connecticut                                    0                 0
# Delaware                                      39                 0
# District of Columbia                         100                 0
# Florida                                      353                 0
# Georgia                                      208                 0
# Hawaii                                         0                 0
# Idaho                                          0                 0
# Illinois                                     834                 0
# Indiana                                      219                 0
# Iowa                                          36                 0
# Kansas                                        10                 0
# Kentucky                                      28                 0
# Louisiana                                    211                 0
# Maine                                          0                 0
#
#                       pneumonia_influenzaor_COVID_deaths  total_deaths
# state
# Alabama                                              309          2871
# Alaska                                                 0           159
# Arizona                                              474          4165
# Arkansas                                             142          1936
# California                                          2101         16950
# Colorado                                             599          3071
# Connecticut                                           45            45
# Delaware                                             137           479
# District of Columbia                                 114           356
# Florida                                             1507         14111
# Georgia                                              638          4455
# Hawaii                                                29           702
# Idaho                                                 50           876
# Illinois                                            2084          9023
# Indiana                                              815          3976
# Iowa                                                 279          1904
# Kansas                                               141          1682
# Kentucky                                             265          2141
# Louisiana                                            528          2348
# Maine                                                 89          1029

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/cdc_may_data_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['cdc_covid_data']

# %% [markdown]
# ### Load DataFrames into database

# %%
cdc_may_group_data.to_sql(name='cdc_covid_data', con=engine, if_exists='append', index=True)
